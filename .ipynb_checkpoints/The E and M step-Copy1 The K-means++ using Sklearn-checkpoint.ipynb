# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# ### Dataset Preparation --

# %%
x,y = make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
print(type(x))
print(x[0:4])
print(y[0:4])
# Out:
# <class 'numpy.ndarray'>
# [[-6.94238952 -6.8807223 ]
#  [ 8.14492336  7.52724561]
#  [-3.61995355 -0.07726913]
#  [-8.91918262 -6.772189  ]]
# [3 2 1 3]

# %%
plt.figure(0)
plt.grid("on")
plt.style.use('default')
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
k = 5
color = ["green","red","blue","yellow","orange"]


#dictionary declared
clusters = {}

for i in range(k):
    center = 10*(2*np.random.random((x.shape[1],))-1)
    points = []
    
    cluster = {
        'center':center,
         'points':points,
         'color':color[i]
    }
    
    clusters[i]=cluster

# %%
# this is basically a dictionary of clusters
clusters
# Out:
# {0: {'center': array([-1.17867427, -6.56695711]),
#   'points': [],
#   'color': 'green'},
#  1: {'center': array([-9.11068418, -7.11681464]),
#   'points': [],
#   'color': 'red'},
#  2: {'center': array([-5.87914987, -5.2443509 ]),
#   'points': [],
#   'color': 'blue'},
#  3: {'center': array([-9.17263179,  3.21718658]),
#   'points': [],
#   'color': 'yellow'},
#  4: {'center': array([-4.77528402,  8.57296431]),
#   'points': [],
#   'color': 'orange'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
# Just a little testing 

v1=np.array([1,2])
v2=np.array([3,4])

print(distance(v1,v2))
# Out:
# 2.8284271247461903

# %%
# Assign each and every point to some cluster
# E - Step
def AssignPointtoClusters(clusters):
    for i in range(x.shape[0]):
        dist = []
        currx = x[i]

        for j in range(k):
            d = distance(currx,clusters[j]['center'])
            dist.append(d)

        current_cluster = np.argmin(dist)
        clusters[current_cluster]['points'].append(currx)

def Updateclusters(clusters): #  M step
    for i in range(k):
        pts = np.array(clusters[i]['points'])
        
        if pts.shape[0]>0:
            new_center = pts.mean(axis=0)
            
            clusters[i]['center'] = new_center
            clusters[i]['points'] = []
            
            

def plotclusters(clusters):
    for i in range(k):
        print(len(clusters[i]['points']))
        
        pts = np.array(clusters[i]['points'])
        
        # plot the point 
        
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[i]['color'])
        except:
            pass
        
        # plot the cluster center
        
        uk = clusters[i]['center']
        
        plt.scatter(uk[0],uk[1],color="black",marker="*")

# %%
AssignPointtoClusters(clusters)
plotclusters(clusters)
Updateclusters(clusters)
# Out:
# 100
# 99
# 98
# 103
# 100
